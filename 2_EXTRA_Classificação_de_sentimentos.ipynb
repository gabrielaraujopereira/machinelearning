# %% [markdown]
# <a href="https://colab.research.google.com/github/gabrielaraujopereira/machinelearning/blob/main/2_EXTRA_Classifica%C3%A7%C3%A3o_de_sentimentos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Criando uma base numa lista e transformando num DataFrame

# %%
#Importando uma biblioteca de Processamento de Linguaguem natural
import nltk

# %%
#base criada na mão, com frases aleatórias
base = [('não precisei pagar o ingresso','alegria'),
('se eu ajeitar tudo fica bem','alegria'),
('minha fortuna ultrapassa a sua','alegria'),
('sou muito afortunado','alegria'),
('e benefico para todos esta nova medida','alegria'),
('ficou lindo','alegria'),
('achei esse sapato muito simpático','alegria'),
('estou ansiosa pela sua chegada','alegria'),
('congratulações pelo seu aniversário','alegria'),
('delicadamente ele a colocou para dormir','alegria'),
('a musica e linda','alegria'),
('sem musica eu não vivo','alegria'),
('conclui uma tarefa muito difícil','alegria'),
('conclui minha graduação','alegria'),
('estou muito contente com tudo','alegria'),
('eu confio em você','alegria'),
('e um prazer conhecê-lo','alegria'),
('o coleguismo de vocês e animador','alegria'),
('estou aproveitando as ferias','alegria'),
('vamos aproveitar as ferias','alegria'),
('e muito divertido este jogo','alegria'),
('vamos ter muita diversão','alegria'),
('não achei que me divertiria tanto assim','alegria'),
('vou consentir o orçamento ao cliente','alegria'),
('com o consentimento dos meus pais podemos nos casar','alegria'),
('eu adorei este perfume','alegria'),
('sua bondade e cativante','alegria'),
('estou despreocupada','alegria'),
('não me preocupo com o que aconteceu','alegria'),
('me sinto completamente segura','alegria'),
('estimo muito o seu trabalho','alegria'),
('somos estimados por nossa família','alegria'),
('concretizamos nossa ideia','alegria'),
('nosso ideal foi alcançado','alegria'),
('estamos muito felizes juntos','alegria'),
('estou tão animada com os preparativos para o casamento','alegria'),
('você será muito amado meu filho','alegria'),
('os apaixonados são maravilhosos','alegria'),
('agradeço imensamente o seu apoio nestes dias','alegria'),
('esta comida me parece muito atraente','alegria'),
('você me completa','alegria'),
('poderemos completar o projeto hoje!','alegria'),
('estamos namorando','alegria'),
('estou namorando este vestido a um tempo','alegria'),
('pude comprar meu celular hoje','alegria'),
('e um deleite poder compartilhar minhas vitórias','alegria'),
('ela e um boa garota','alegria'),
('estivemos em um ótimo show','alegria'),
('este trabalho e agradável','alegria'),
('gosto de ficar no seu aconchego','alegria'),
('fiz a adesão ao curso hoje','alegria'),
('eu sou admirada por muitos','alegria'),
('adoro como você e','alegria'),
('adoro seu cabelo macio','alegria'),
('adoro a cor dos seus olhos','alegria'),
('somo tão amáveis um com o outro','alegria'),
('sinto uma grande afeição por ele','alegria'),
('quero agradar meus filhos','alegria'),
('me sinto completamente amado','alegria'),
('eu amo você','alegria'),
('que grande alivio','alegria'),
('a dor esta amenizando finalmente','alegria'),
('acho que me apaixonei','alegria'),
('amar e maravilhoso','alegria'),
('estou me sentindo muito animada','alegria'),
('me sinto muito bem hoje','alegria'),
('como o luar e belo','alegria'),
('o dia esta muito bonito','alegria'),
('nossa como sou afortunado','alegria'),
('as maravilhas do mundo','alegria'),
('recebi muito carinho hoje do meus colegas','alegria'),
('estou me sentindo reconfortada hoje','alegria'),
('e muito bom estar com os amigos','alegria'),
('estou muito contente com o resultado dos testes','alegria'),
('essa pintura esta bem brilhante','alegria'),
('temos água em abundancia','alegria'),
('que roupa delicada','alegria'),
('você e um grande comediante','alegria'),
('que bondade a sua em vir aqui','alegria'),
('o amor e lindo','alegria'),
('nossa amizade vai durar para sempre','alegria'),
('estou eufórica com a noticia','alegria'),
('ele e realmente fiel a mim','alegria'),
('vou dar uma grande festa para comemorar meu aniversário','alegria'),
('graças a deus que eu enxerguei o certo','alegria'),
('essa e a melhor escolhas de todas','alegria'),
('o mais incrível e você minha bela','alegria'),
('e tão engraçado tentar explicar','alegria'),
('e emocionante estar neste lugar','alegria'),
('estou cativada pelo seu olhar','alegria'),
('estou loucamente apaixonada','alegria'),
('eu nunca tive duvidas','alegria'),
('estou rodeada pelo seu abraço','alegria'),
('eu vejo estrelas pelo caminho','alegria'),
('eu sinto o sol sempre que você esta por perto','alegria'),
('eu estou sorrindo de orelha a orelha','alegria'),
('isso vale a pena','alegria'),
('finalmente você colocou meu amor em primeiro lugar','alegria'),
('nós dançamos noite adentro','alegria'),
('seu amor e brilhante','alegria'),
('toquei muitos corações durante o meu caminho','alegria'),
('eu serei sua amiga e companheira','alegria'),
('você me traz de volta a vida','alegria'),
('você e como um sonho doce','alegria'),
('adoro este doce de frutas','alegria'),
('meu suco favorito','alegria'),
('estou agradecida pela ajuda','alegria'),
('e um enorme prazer ter você em nossa equipe','alegria'),
('trabalhar em equipe e o melhor','alegria'),
('me sinto flutuando no ar','alegria'),
('a brisa esta agradável hoje','alegria'),
('ótimo e compatível','alegria'),
('somos compatíveis um com o outro','alegria'),
('o órgão e compatível com o paciente','alegria'),
('estou contente fui aceita na faculdade','alegria'),
('fui aprovada no meu exame','alegria'),
('fui beneficiada pela minha empresa','alegria'),
('eu sou muito cativante','alegria'),
('estou contente com o apoio','alegria'),
('como este lugar e confortável','alegria'),
('e bom estar quente neste frio','alegria'),
('um elogio nunca e demais','alegria'),
('vou te chamar para comemorar','alegria'),
('e desejável a sua presença em nossa apresentação','alegria'),
('sou muito grata a você','alegria'),
('me dedico muito naquilo que faço','alegria'),
('estou completamente apaixonada ','alegria'),
('vamos agitar essa noite ','alegria'),
('você significa muito para mim','alegria'),
('vamos agir sem preconceitos e julgamentos','alegria'),
('finalmente completei a minha coleção, maravilhoso','alegria'),
('eu sou sua rainha ','alegria'),
('satisfatoriamente eu anuncio o vencedor dos jogos','alegria'),
('você me atrai facilmente ','alegria'),
('aquele rapaz e extremamente atraente','alegria'),
('sinto-me viva ','alegria'),
('sinto-me em paz ','alegria'),
('estamos tendo muito lucro','alegria'),
('muito bem esta tudo em ordem agora ','alegria'),
('podemos arrumar um emprego juntos ','alegria'),
('a arrumação esta terminada, que alívio','alegria'),
('o câncer e benigno ','alegria'),
('o amor e abundante','alegria'),
('vamos ser caridosos este natal','alegria'),
('com todo esse charme você irá atrair a todos','alegria'),
('nossa como você e charmoso querido ','alegria'),
('sou querida pelos meu amigos','alegria'),
('seja cuidadoso com os meus sentimentos','alegria'),
('estou comovido com tamanha caridade','alegria'),
('um chá quente e reconfortante','alegria'),
('que alegria ter vocês aqui ','alegria'),
('vamos aplaudir o vencedor ','alegria'),
('palmas para a aniversariante','alegria'),
('desejo a você tudo de bom','alegria'),
('hora de apreciar um bom vinho','alegria'),
('aprecio sua presença em minha escola','alegria'),
('anseio por seus próximos trabalhos','alegria'),
('maravilhoso jogo amistoso','alegria'),
('e ótimo que os ânimos tenham se apaziguado','alegria'),
('concretizei finalmente meu sonho','alegria'),
('O coração se enche de luz com novos começos', 'alegria'),
('Pequenos momentos iluminam o dia', 'alegria'),
('Um sorriso é o reflexo da felicidade', 'alegria'),
('Compartilhar com amigos traz calor ao coração', 'alegria'),
('Abraçar quem amamos é o maior presente', 'alegria'),
('Curtir o pôr do sol em boa companhia é mágico', 'alegria'),
('Alcançar nossos sonhos é realização plena', 'alegria'),
('Rir é a linguagem universal da alma', 'alegria'),
('Dançar como se ninguém estivesse olhando é libertador', 'alegria'),
('A música que toca a alma nos faz vibrar', 'alegria'),
('Um abraço apertado e sincero aquece o coração', 'alegria'),
('Boas notícias inesperadas são como bálsamo para a alma', 'alegria'),
('Encontrar a paz interior é uma jornada incrível', 'alegria'),
('A natureza em sua plenitude é uma dádiva', 'alegria'),
('Fazer o que amamos é a essência da vida', 'alegria'),
('Superar desafios nos torna mais fortes', 'alegria'),
('Novas aventuras nos fazem sentir vivos', 'alegria'),
('Tempo com a família é um tesouro inestimável', 'alegria'),
('Ver um projeto se concretizar é uma conquista', 'alegria'),
('Aprender algo novo é uma fonte de inspiração', 'alegria'),
('A brisa do mar nos renova e revigora', 'alegria'),
('Celebrar datas especiais é uma festa para a alma', 'alegria'),
('Viajar e explorar novos horizontes é uma jornada emocionante', 'alegria'),
('Receber elogios genuínos nos enche de gratidão', 'alegria'),
('O amor compartilhado é um presente divino', 'alegria'),
('Recordar momentos felizes traz um sorriso ao rosto', 'alegria'),
('Fazer alguém sorrir é espalhar alegria', 'alegria'),
('Ver uma criança crescer é testemunhar a maravilha da vida', 'alegria'),
('Reencontrar velhos amigos é reacender a chama da amizade', 'alegria'),
('Saborear um prato delicioso é uma experiência única', 'alegria'),
('Torcer pelo time do coração é pura emoção', 'alegria'),
('Contemplar um céu estrelado nos faz sonhar', 'alegria'),
('Receber flores é um gesto de carinho', 'alegria'),
('Presentes inesperados aquecem o coração', 'alegria'),
('Sentir o calor do sol no rosto nos energiza', 'alegria'),
('Festas animadas são motivo de celebração', 'alegria'),
('Abraçar a vida com entusiasmo é viver plenamente', 'alegria'),
('Encontrar soluções criativas é uma revelação', 'alegria'),
('Descobrir a beleza do mundo é uma dádiva', 'alegria'),
('Rir de si mesmo com leveza é libertador', 'alegria'),
('Celebrar a diversidade do mundo é enriquecedor', 'alegria'),
('Sentir-se vivo a cada instante é uma bênção', 'alegria'),
('Abraçar a jornada da vida com gratidão é iluminador', 'alegria'),
('Encontrar amor e amizade em todos os lugares é mágico', 'alegria'),
('Sentir a energia contagiante da natureza é revigorante', 'alegria'),
('Viver o presente com intensidade é uma escolha', 'alegria'),
('Encontrar beleza mesmo nas situações difíceis é uma lição', 'alegria'),
('Criar memórias preciosas é um tesouro', 'alegria'),
('Ser gentil e generoso com o próximo é nobre', 'alegria'),
('Ver o potencial infinito em cada pessoa é inspirador', 'alegria'),
('Transformar obstáculos em oportunidades é uma vitória', 'alegria'),
('Compartilhar histórias inspiradoras é uma dádiva', 'alegria'),
('Sentir-se em casa em qualquer lugar é acolhedor', 'alegria'),
('Explorar o mundo é uma aventura sem fim', 'alegria'),
('Inspirar-se por grandes mentes criativas é enriquecedor', 'alegria'),
('Maravilhar-se com as maravilhas do universo é fascinante', 'alegria'),
('Deliciar-se com sabores e aromas é uma experiência sensorial', 'alegria'),
('Contemplar as estrelas nos faz sonhar alto', 'alegria'),
('Celebração é uma manifestação de alegria', 'alegria'),
('Abraçar a jornada da vida com coragem é transformador', 'alegria'),
('Encontrar força em momentos difíceis é uma lição de vida', 'alegria'),
('Enxergar o potencial em cada amanhecer é inspirador', 'alegria'),
('Ser um farol de positividade é um dom', 'alegria'),
('Cultivar relacionamentos genuínos é um tesouro', 'alegria'),
('Espalhar amor e alegria é uma missão nobre', 'alegria'),
('Criar um ambiente de harmonia e paz é transformador', 'alegria'),
('Viver com gratidão é uma escolha sábia', 'alegria'),
('Olhar para o futuro com esperança é revigorante', 'alegria'),
('Ser inspirado por grandes mentes é enriquecedor', 'alegria'),
('Surpreender-se com a beleza do mundo natural é fascinante', 'alegria'),
('Deleitar-se com sabores e aromas é um prazer', 'alegria'),
('Maravilhar-se com as maravilhas do universo é uma dádiva', 'alegria'),
('Celebrar a jornada da vida com coragem é inspirador', 'alegria'),
('Encontrar força em momentos difíceis é uma lição valiosa', 'alegria'),
('Enxergar o potencial em cada novo dia é motivador', 'alegria'),
('Ser uma fonte de positividade para os outros é gratificante', 'alegria'),
('Cultivar relacionamentos autênticos é uma riqueza', 'alegria'),
('Espalhar amor e alegria é uma bênção', 'alegria'),
('Criar um ambiente de harmonia e serenidade é transformador', 'alegria'),
('Ser grato por todas as bênçãos é enriquecedor', 'alegria'),
('Olhar para o futuro com otimismo é inspirador', 'alegria'),
('Ser inspirado por mentes criativas é estimulante', 'alegria'),
('Surpreender-se com a beleza da natureza é encantador', 'alegria'),
('Deleitar-se com sabores e aromas deliciosos é uma experiência única', 'alegria'),
('Maravilhar-se com as maravilhas do universo é uma jornada fascinante', 'alegria'),
('Celebrar a jornada da vida com determinação é recompensador', 'alegria'),
('Encontrar força e resiliência em momentos desafiadores é inspirador', 'alegria'),
('Enxergar o potencial infinito em cada amanhecer é revigorante', 'alegria'),
('Ser um farol de positividade e esperança para os outros é uma dádiva', 'alegria'),
('Cultivar relacionamentos significativos é uma fonte de alegria', 'alegria'),
('Espalhar amor e carinho pelo mundo é uma missão nobre', 'alegria'),
('Criar um ambiente de harmonia e serenidade é transformador', 'alegria'),
('Ser grato por todas as bênçãos da vida é enriquecedor', 'alegria'),
('Olhar para o futuro com esperança e otimismo é revigorante', 'alegria'),
('Ser inspirado por grandes mentes criativas é inspirador', 'alegria'),
('Surpreender-se com a beleza do mundo natural é uma experiência enriquecedora', 'alegria'),
('Deleitar-se com sabores e aromas deliciosos é um verdadeiro prazer', 'alegria'),
('Maravilhar-se com as maravilhas do universo nos faz sonhar alto', 'alegria'),
('Celebrar a jornada da vida com coragem e determinação é gratificante', 'alegria'),
('Encontrar força e resiliência em momentos desafiadores é transformador', 'alegria'),
('Enxergar o potencial infinito em cada novo dia é inspirador', 'alegria'),
('Ser um farol de positividade e esperança para os outros é motivador', 'alegria'),
('Cultivar relacionamentos autênticos e significativos é enriquecedor', 'alegria'),
('Espalhar amor e alegria pelo mundo é uma missão nobre e gratificante', 'alegria'),
('Criar um ambiente de harmonia e serenidade é transformador', 'alegria'),
('Ser grato por todas as bênçãos da vida é uma escolha sábia', 'alegria'),
('Olhar para o futuro com esperança e otimismo nos enche de energia', 'alegria'),
('Ser inspirado por mentes criativas e visionárias é enriquecedor', 'alegria'),
('Surpreender-se com a beleza da natureza é uma experiência encantadora', 'alegria'),
('Deleitar-se com sabores e aromas deliciosos é uma verdadeira festa para os sentidos', 'alegria'),
('Maravilhar-se com as maravilhas do universo nos faz sonhar alto', 'alegria'),
('Celebrar a jornada da vida com coragem e determinação é uma conquista', 'alegria'),
('Encontrar força e resiliência em momentos desafiadores é inspirador', 'alegria'),
('Ser um farol de positividade e esperança para os outros é uma dádiva', 'alegria'),
('Cultivar relacionamentos autênticos e significativos é enriquecedor', 'alegria'),
('Espalhar amor e alegria pelo mundo é uma missão nobre e gratificante', 'alegria'),
('Criar um ambiente de harmonia e serenidade é transformador', 'alegria'),
('Ser grato por todas as bênçãos da vida é uma escolha sábia', 'alegria'),
('Olhar para o futuro com esperança e otimismo nos enche de energia', 'alegria'),
('Ser inspirado por mentes criativas e visionárias é enriquecedor', 'alegria'),
('Surpreender-se com a beleza da natureza é uma experiência encantadora', 'alegria'),
('Deleitar-se com sabores e aromas deliciosos é uma verdadeira festa para os sentidos', 'alegria'),
('Maravilhar-se com as maravilhas do universo nos faz sonhar alto', 'alegria'),
('Celebrar a jornada da vida com coragem e determinação é uma conquista', 'alegria'),
('Encontrar força e resiliência em momentos desafiadores é inspirador', 'alegria'),
('Enxergar o potencial infinito em cada novo dia nos motiva', 'alegria'),
('Ser um farol de positividade e esperança para os outros é recompensador', 'alegria'),
('Cultivar relacionamentos autênticos e profundos é uma riqueza inestimável', 'alegria'),
('Espalhar amor e alegria é a essência da vida', 'alegria'),
('Criar um ambiente de serenidade e harmonia é transformador', 'alegria'),
('Ser grato por cada bênção é uma atitude enriquecedora', 'alegria'),
('Olhar para o futuro com otimismo e esperança é revigorante', 'alegria'),
('Ser inspirado por mentes criativas e visionárias é inspirador', 'alegria'),
('Surpreender-se com a beleza da natureza é uma experiência mágica', 'alegria'),
('Deleitar-se com sabores e aromas incríveis é uma verdadeira celebração', 'alegria'),
('Maravilhar-se com as maravilhas do universo nos faz sonhar alto e longe', 'alegria'),
('Celebrar a jornada da vida com coragem e determinação é uma vitória', 'alegria'),
('Encontrar força e resiliência em momentos desafiadores é inspirador', 'alegria'),
('Enxergar o potencial infinito em cada novo amanhecer nos motiva', 'alegria'),
('Ser um farol de positividade e esperança é um dom especial', 'alegria'),
('Cultivar relacionamentos autênticos e profundos é uma dádiva', 'alegria'),
('Espalhar amor e alegria é uma missão de vida', 'alegria'),
('Criar um ambiente de serenidade e harmonia é transformador', 'alegria'),
('Ser grato por todas as bênçãos é uma escolha sábia e gratificante', 'alegria'),
('Olhar para o futuro com otimismo e esperança nos enche de entusiasmo', 'alegria'),
('Ser inspirado por mentes criativas e visionárias é enriquecedor', 'alegria'),
('Surpreender-se com a beleza da natureza é uma experiência inesquecível', 'alegria'),
('Deleitar-se com sabores e aromas incríveis é uma verdadeira celebração', 'alegria'),
('Maravilhar-se com as maravilhas do universo nos faz sonhar alto e longe', 'alegria'),
('Celebrar a jornada da vida com coragem e determinação é uma vitória pessoal', 'alegria'),
('Encontrar força e resiliência em momentos desafiadores é inspirador', 'alegria'),
('Enxergar o potencial infinito em cada novo amanhecer nos motiva a seguir em frente', 'alegria'),
('Ser um farol de positividade e esperança é um dom especial que podemos oferecer', 'alegria'),
('Cultivar relacionamentos autênticos e profundos é uma dádiva que enriquece nossa vida', 'alegria'),
('Espalhar amor e alegria é uma missão de vida que nos torna melhores', 'alegria'),
('Criar um ambiente de serenidade e harmonia é transformador e inspirador', 'alegria'),
('Ser grato por todas as bênçãos é uma escolha sábia e enriquecedora', 'alegria'),
('Olhar para o futuro com otimismo e esperança nos enche de entusiasmo e energia', 'alegria'),
('Ser inspirado por mentes criativas e visionárias é uma experiência enriquecedora', 'alegria'),
('Surpreender-se com a beleza da natureza é uma fonte inesgotável de alegria', 'alegria'),
('Deleitar-se com sabores e aromas incríveis é uma verdadeira celebração da vida', 'alegria'),
('Maravilhar-se com as maravilhas do universo nos faz sonhar alto e longe, buscando novos horizontes', 'alegria'),
('Celebrar a jornada da vida com coragem e determinação é uma vitória pessoal que merece reconhecimento', 'alegria'),
('Encontrar força e resiliência em momentos desafiadores é inspirador e nos torna mais fortes', 'alegria'),
('Enxergar o potencial infinito em cada novo amanhecer nos motiva a seguir em frente com paixão', 'alegria'),
('Ser um farol de positividade e esperança é um dom especial que podemos oferecer ao mundo', 'alegria'),
('eu imploro, não me matem!','medo'),
('A escuridão me cerca, sinto medo', 'medo'),
('O medo me paralisa, mas eu vou enfrentá-lo', 'medo'),
('Os olhos do desconhecido me enchem de medo', 'medo'),
('O som assustador ecoa na noite escura', 'medo'),
('A incerteza do amanhã me causa medo', 'medo'),
('Meu coração bate rápido de puro medo', 'medo'),
('A sombra sinistra se aproxima, sinto medo', 'medo'),
('O medo me consome, mas não vou desistir', 'medo'),
('A sensação de perigo iminente é avassaladora', 'medo'),
('A escuridão da floresta me enche de medo', 'medo'),
('Os olhos vazios olham para mim, causando medo', 'medo'),
('A voz trêmula revela meu medo interior', 'medo'),
('O desconhecido espreita nas sombras, causando medo', 'medo'),
('Os pesadelos à noite alimentam meu medo', 'medo'),
('A sensação de estar sendo perseguido é aterrorizante', 'medo'),
('A ansiedade me consome, criando medo', 'medo'),
('O som estranho à porta me enche de medo', 'medo'),
('A escuridão profunda esconde segredos assustadores', 'medo'),
('A sensação de estar sozinho no escuro é perturbadora', 'medo'),
('me sinto intimidada pela sua presença','medo'),
('tenho medo de ser advertida novamente','medo'),
('estou correndo o risco de ser advertido','medo'),
('estou correndo riscos de saúde','medo'),
('os riscos são reais','medo'),
('podemos perder muito dinheiro com essa investida','medo'),
('socorro, fui intimado a depor','medo'),
('fui notificado e estou com medo de perde a guarda da minha filha','medo'),
('estou angustiada com meus filhos na rua','medo'),
('e abominável o que fazem com os animais','medo'),
('foi terrível o tigre quase o matou','medo'),
('me advertiram sobre isso','medo')]

# %%
import numpy as np
import pandas as pd

# %%
type(base)
# Out:
# list

# %% [markdown]
# ## Convertendo uma Lista em um  Dataframe

# %%
basenova = pd.DataFrame(base, columns = ['frase','sentimento'])

# %%
basenova
# Out:
#                                                  frase sentimento
# 0                        não precisei pagar o ingresso    alegria
# 1                          se eu ajeitar tudo fica bem    alegria
# 2                       minha fortuna ultrapassa a sua    alegria
# 3                                 sou muito afortunado    alegria
# 4               e benefico para todos esta nova medida    alegria
# ..                                                 ...        ...
# 588  fui notificado e estou com medo de perde a gua...       medo
# 589            estou angustiada com meus filhos na rua       medo
# 590            e abominável o que fazem com os animais       medo
# 591                 foi terrível o tigre quase o matou       medo
# 592                           me advertiram sobre isso       medo
#
# [593 rows x 2 columns]

# %%
basenova.shape
# Out:
# (593, 2)

# %%
#Embraralhando a base
import sklearn
basenova = sklearn.utils.shuffle(basenova)

# %%
basenova
# Out:
#                                                  frase sentimento
# 150                        que alegria ter vocês aqui     alegria
# 181                         meu deus, ele desapareceu!       medo
# 44                       pude comprar meu celular hoje    alegria
# 23                vou consentir o orçamento ao cliente    alegria
# 246                                  estou amedrontada       medo
# ..                                                 ...        ...
# 172           vou ficar sem mesada se tirar nota baixa       medo
# 101                   eu serei sua amiga e companheira    alegria
# 132  satisfatoriamente eu anuncio o vencedor dos jogos    alegria
# 96                                    isso vale a pena    alegria
# 142                                 o amor e abundante    alegria
#
# [280 rows x 2 columns]

# %%
#para acessar um item quando é uma lista
base[1]
# Out:
# ('se eu ajeitar tudo fica bem', 'alegria')

# %%
#para acessar um item quando é um dataframe
basenova.iloc[[1]]
# Out:
#                          frase sentimento
# 1  se eu ajeitar tudo fica bem    alegria

# %%
#quantidade de linhas de um dataframe
basenova.shape
# Out:
# (593, 2)

# %%
#quantidade de linhas de uma lista
len(base)
# Out:
# 593

# %%
import seaborn as sns
sns.countplot(x= basenova['sentimento'], label = 'Contagem');

# %% [markdown]
# ## Separar texto do rótulo - O sentimento é o que queremos prever, então fica separado.

# %%
frases = basenova[['frase']]
sentimento = basenova['sentimento'].values

# %%
frases.head()
# Out:
#                                     frase
# 0           não precisei pagar o ingresso
# 1             se eu ajeitar tudo fica bem
# 2          minha fortuna ultrapassa a sua
# 3                    sou muito afortunado
# 4  e benefico para todos esta nova medida

# %%
sentimento
# Out:
# array(['alegria', 'alegria', 'alegria', 'alegria', 'alegria', 'alegria',
#        'alegria', 'alegria', 'alegria', 'alegria', 'alegria', 'alegria',
#        'alegria', 'alegria', 'alegria', 'alegria', 'alegria', 'alegria',
#        'alegria', 'alegria', 'alegria', 'alegria', 'alegria', 'alegria',
#        'alegria', 'alegria', 'alegria', 'alegria', 'alegria', 'alegria',
#        'alegria', 'alegria', 'alegria', 'alegria', 'alegria', 'alegria',
#        'alegria', 'alegria', 'alegria', 'alegria', 'alegria', 'alegria',
#        'alegria', 'alegria', 'alegria', 'alegria', 'alegria', 'alegria',
#        'alegria', 'alegria', 'alegria', 'alegria', 'alegria', 'alegria',
#        'alegria', 'alegria', 'alegria', 'alegria', 'alegria', 'alegria',
#        'alegria', 'alegria', 'alegria', 'alegria', 'alegria', 'alegria',
#        'alegria', 'alegria', 'alegria', 'alegria', 'alegria', 'alegria',
#        'alegria', 'alegria', 'alegria', 'alegria', 'alegria', 'alegria',
# ...

# %% [markdown]
# ## Remoção das Stop Words apenas das frases, realmente ver se vale a pena fazer com ou sem.

# %%
#posso criar minha própria lista de stop words
'''stopwords = ['a', 'agora', 'algum', 'alguma', 'aquele', 'aqueles', 'de', 'deu', 'do', 'e', 'estou', 'esta', 'esta',
             'ir', 'meu', 'muito', 'mesmo', 'no', 'nossa', 'o', 'outro', 'para', 'que', 'sem', 'talvez', 'tem', 'tendo',
             'tenha', 'teve', 'tive', 'todo', 'um', 'uma', 'umas', 'uns', 'vou']'''
# Out:
# "stopwords = ['a', 'agora', 'algum', 'alguma', 'aquele', 'aqueles', 'de', 'deu', 'do', 'e', 'estou', 'esta', 'esta',\n             'ir', 'meu', 'muito', 'mesmo', 'no', 'nossa', 'o', 'outro', 'para', 'que', 'sem', 'talvez', 'tem', 'tendo',\n             'tenha', 'teve', 'tive', 'todo', 'um', 'uma', 'umas', 'uns', 'vou']"

# %%
#ou posso fazer o download de uma
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#pegando em portugues
stopwordsnltk = nltk.corpus.stopwords.words('portuguese')

# %%
stopwordsnltk
# Out:
# ['a',
#  'à',
#  'ao',
#  'aos',
#  'aquela',
#  'aquelas',
#  'aquele',
#  'aqueles',
#  'aquilo',
#  'as',
#  'às',
#  'até',
#  'com',
#  'como',
#  'da',
#  'das',
#  'de',
#  'dela',
#  'delas',
#  'dele',
#  'deles',
#  'depois',
#  'do',
#  'dos',
#  'e',
#  'é',
#  'ela',
#  'elas',
#  'ele',
#  'eles',
#  'em',
#  'entre',
#  'era',
#  'eram',
#  'éramos',
#  'essa',
#  'essas',
#  'esse',
#  'esses',
#  'esta',
#  'está',
#  'estamos',
#  'estão',
#  'estar',
#  'estas',
#  'estava',
#  'estavam',
#  'estávamos',
#  'este',
#  'esteja',
#  'estejam',
#  'estejamos',
#  'estes',
#  'esteve',
#  'estive',
#  'estivemos',
#  'estiver',
#  'estivera',
#  'estiveram',
#  'estivéramos',
#  'estiverem',
#  'estivermos',
#  'estivesse',
#  'estivessem',
#  'estivéssemos',
#  'estou',
#  'eu',
#  'foi',
#  'fomos',
#  'for',
#  'fora',
#  'foram',
#  'fôramos',
#  'forem',
#  'formos',
#  'fosse',
#  'fossem',
#  'fôssemos',
#  'fui',
#  'há',
#  'haja',
#  'hajam',
#  'hajamos',
# ...

# %%
#Criando uma função para retirar as stopwords das frases, já que elas vão ter na frase de medo ou alegria
def removestopwords(text):
    textolimpo = " " # cria uma lista vazia
    doc = text.lower() # Transformando em minúsculo
    separado = doc.split() # transforma em lista de palavras
    for palavra in separado: #vai pegando cada palavra da lista
        if palavra not in stopwordsnltk: # compara cada palavra com a lista de stopwords
          textolimpo += palavra + " " #adiciona cada palavraq que não está nas stopwords na frase
    return textolimpo

# %%
fraseteste = "Eu não sei o porquê, mas amo viajar"

# %%
removestopwords(fraseteste)
# Out:
# ' sei porquê, amo viajar '

# %% [markdown]
# ### aplicando a função na base de dados toda

# %%
frases['frase'] = frases['frase'].apply(removestopwords)
# Out:
# <ipython-input-77-31c157ed447f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   frases['frase'] = frases['frase'].apply(removestopwords)

# %%
frases
# Out:
#                                     frase
# 0                precisei pagar ingresso
# 1                  ajeitar tudo fica bem
# 2                     fortuna ultrapassa
# 3                             afortunado
# 4             benefico todos nova medida
# ..                                    ...
# 588   notificado medo perde guarda filha
# 589                angustiada filhos rua
# 590             abominável fazem animais
# 591           terrível tigre quase matou
# 592                     advertiram sobre
#
# [593 rows x 1 columns]

# %% [markdown]
# ##Separar a base de dados, separando 25% da base para ficar para teste

# %%
from sklearn.model_selection import train_test_split
frases_treino, frases_teste, senti_treino, senti_teste = train_test_split(frases, sentimento, test_size=0.25,shuffle=True)

# %%
frases_treino
# Out:
#                                                  frase
# 190                   torcer time coração pura emoção
# 588                notificado medo perde guarda filha
# 38             agradeço imensamente apoio nestes dias
# 259   encontrar força resiliência momentos desafiad...
# 60                                      grande alivio
# ..                                                 ...
# 311   enxergar potencial infinito cada novo amanhec...
# 104                                 adoro doce frutas
# 522                            saída, preciso milagre
# 215      maravilhar-se maravilhas universo fascinante
# 12                             conclui tarefa difícil
#
# [444 rows x 1 columns]

# %%
senti_treino
# Out:
# array(['alegria', 'medo', 'alegria', 'alegria', 'alegria', 'medo',
#        'alegria', 'alegria', 'medo', 'alegria', 'alegria', 'medo',
#        'alegria', 'medo', 'alegria', 'medo', 'alegria', 'alegria',
#        'alegria', 'alegria', 'alegria', 'alegria', 'medo', 'alegria',
#        'medo', 'medo', 'alegria', 'alegria', 'medo', 'alegria', 'medo',
#        'alegria', 'medo', 'medo', 'medo', 'medo', 'alegria', 'alegria',
#        'alegria', 'alegria', 'medo', 'alegria', 'alegria', 'alegria',
#        'medo', 'medo', 'medo', 'medo', 'alegria', 'alegria', 'medo',
#        'medo', 'alegria', 'alegria', 'medo', 'alegria', 'alegria',
#        'alegria', 'alegria', 'alegria', 'alegria', 'alegria', 'medo',
#        'medo', 'medo', 'alegria', 'medo', 'alegria', 'alegria', 'alegria',
#        'medo', 'alegria', 'medo', 'alegria', 'alegria', 'alegria',
#        'alegria', 'alegria', 'alegria', 'alegria', 'medo', 'alegria',
# ...

# %%
#essas vou usar para ensinar a IA
frases_treino.shape
# Out:
# (444, 1)

# %%
senti_treino.shape
# Out:
# (444,)

# %%
# com essas vou ver se ela aprendeu
frases_teste.shape
# Out:
# (149, 1)

# %% [markdown]
# ## Agora que nossa base está separada vamos converter nossos textos em números para a Inteligência Artificial. Processo de Vetorização de Palavras

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
vocab = basenova['frase'].values

# %%
vocab
# Out:
# array(['não precisei pagar o ingresso', 'se eu ajeitar tudo fica bem',
#        'minha fortuna ultrapassa a sua', 'sou muito afortunado',
#        'e benefico para todos esta nova medida', 'ficou lindo',
#        'achei esse sapato muito simpático',
#        'estou ansiosa pela sua chegada',
#        'congratulações pelo seu aniversário',
#        'delicadamente ele a colocou para dormir', 'a musica e linda',
#        'sem musica eu não vivo', 'conclui uma tarefa muito difícil',
#        'conclui minha graduação', 'estou muito contente com tudo',
#        'eu confio em você', 'e um prazer conhecê-lo',
#        'o coleguismo de vocês e animador', 'estou aproveitando as ferias',
#        'vamos aproveitar as ferias', 'e muito divertido este jogo',
#        'vamos ter muita diversão',
#        'não achei que me divertiria tanto assim',
#        'vou consentir o orçamento ao cliente',
#        'com o consentimento dos meus pais podemos nos casar',
# ...

# %%
vectorizer = CountVectorizer()
vectorizer.fit_transform(vocab)
vectorizer.get_feature_names_out()
# Out:
# array(['abominável', 'abraço', 'abundancia', 'abundante', 'acabaremos',
#        'aceita', 'achar', 'achei', 'acho', 'aconchego', 'acontecer',
#        'aconteceu', 'adentro', 'adesão', 'admirada', 'adorei', 'adoro',
#        'advertida', 'advertido', 'advertiram', 'afeição', 'afogar',
#        'afortunado', 'afugenta', 'afugentar', 'afugente', 'afundando',
#        'agir', 'agitar', 'agora', 'agradar', 'agradecida', 'agradeço',
#        'agradável', 'agüento', 'ajeitar', 'ajuda', 'ajudem', 'alarmar',
#        'alcançado', 'alegria', 'alguem', 'alivio', 'alívio', 'amado',
#        'amar', 'ameaçando', 'amedrontada', 'amedrontado', 'amedrontar',
#        'amenizando', 'amiga', 'amigos', 'amistoso', 'amizade', 'amo',
#        'amor', 'amáveis', 'angustia', 'angustiada', 'angustiadamente',
#        'animada', 'animador', 'animais', 'aniversariante', 'aniversário',
#        'anseio', 'ansiosa', 'anuncio', 'ao', 'apaixonada', 'apaixonados',
# ...

# %%
vectorizer.vocabulary_
# Out:
# {'que': 507,
#  'alegria': 40,
#  'ter': 600,
#  'vocês': 648,
#  'aqui': 90,
#  'meu': 397,
#  'deus': 234,
#  'ele': 257,
#  'desapareceu': 222,
#  'pude': 502,
#  'comprar': 180,
#  'celular': 150,
#  'hoje': 341,
#  'vou': 651,
#  'consentir': 189,
#  'orçamento': 446,
#  'ao': 69,
#  'cliente': 160,
#  'estou': 287,
#  'amedrontada': 47,
#  'sou': 577,
#  'muito': 410,
#  'afortunado': 22,
#  'finalmente': 320,
#  'completei': 179,
#  'minha': 401,
#  'coleção': 164,
#  'maravilhoso': 385,
#  'tenho': 598,
#  'correr': 196,
#  'pra': 489,
#  'não': 438,
#  'me': 391,
#  'pegarem': 461,
#  'amor': 56,
#  'lindo': 371,
#  'se': 540,
#  'eu': 293,
#  'achar': 6,
#  'vai': 628,
#  'descobrir': 224,
#  'verdade': 634,
#  'ei': 255,
#  'cuidado': 200,
#  'você': 647,
#  'bater': 118,
#  'no': 427,
#  'poste': 487,
#  'certeza': 151,
#  'seguro': 544,
#  'anseio': 66,
#  'por': 485,
#  'seus': 562,
#  'próximos': 501,
#  'trabalhos': 618,
#  'assombrado': 103,
#  'pela': 462,
# ...

# %%
frases_transformadas_treino = vectorizer.transform(frases_treino['frase'].values)
frases_transformadas_teste = vectorizer.transform(frases_teste['frase'].values)

# %%
frases_transformadas_treino
# Out:
# <444x658 sparse matrix of type '<class 'numpy.int64'>'
# 	with 813 stored elements in Compressed Sparse Row format>

# %%
frases_transformadas_treino.shape
# Out:
# (444, 658)

# %%
frases_transformadas_teste.shape
# Out:
# (149, 658)

# %% [markdown]
# # Somente agora entra a parte de Inteligência Artificial (Aprendizado de Máquina) - Vamos Usar 2 modelos de Algoritmos diferentes para comparar o desempenho

# %% [markdown]
# ## Modelo DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, classification_report
#from sklearn.metrics import plot_confusion_matrix
from sklearn import metrics
from sklearn.metrics import ConfusionMatrixDisplay

# %%
arvore = DecisionTreeClassifier(max_depth=6, criterion='gini')
arvore.fit(frases_transformadas_treino,senti_treino) # aqui estou ensinando para a Máquina
y_pred_arvore = arvore.predict(frases_transformadas_teste) # aqui eu não mostro o sentimento porque ele vai ter que advinhar
score_arvore = arvore.score(frases_transformadas_teste, senti_teste) #ver o percentual de acerto
print(score_arvore)
confusion_matrix(senti_teste,y_pred_arvore)
# Out:
# 0.7181208053691275
# array([[87,  0],
#        [42, 20]])

# %%
report=classification_report(y_true=senti_teste,y_pred=y_pred_arvore)
print(report) #Mostra as métricas de resultado do modelo
# Out:
#               precision    recall  f1-score   support
#
#      alegria       0.67      1.00      0.81        87
#         medo       1.00      0.32      0.49        62
#
#     accuracy                           0.72       149
#    macro avg       0.84      0.66      0.65       149
# weighted avg       0.81      0.72      0.67       149

# %%
import matplotlib as plt

# %%
ConfusionMatrixDisplay.from_estimator(arvore, frases_transformadas_teste,senti_teste, cmap=plt.cm.Reds,normalize='true')

# %% [markdown]
# ### Testando com frases aleatórias criadas por vocês, que não estavam na base

# %%
#frase_nova = ['Fiquei muito feliz em saber deste novo curso oferecido na Etec']
#frase_nova = ['Eu me sinto péssimo quando você não vem']
frase_nova = ['Eu adorei este presente']
#frase_nova = ['Socorro estou sendo assaltado']
#frase_nova =['estou sentindo arrepios de medo acho que vi um fantasma']
#frase_nova = ['Nossa estou muito feliz porque acabei de chegar em casa e vou jogar video game']
# convertendo a frase em números
frase_nova_convertida = vectorizer.transform(frase_nova)
y_pred_arvore_unica = arvore.predict(frase_nova_convertida) # aqui eu coloco para o modelo advinhar a nova frase
y_pred_arvore_unica

# %%
percentual_acerto = arvore.predict_proba(frase_nova_convertida)
percentual_acerto

# %% [markdown]
# ## Modelo GradientBoostingClassifier

# %%
xgb = GradientBoostingClassifier(n_estimators=3000,min_samples_leaf = 4, learning_rate=0.1, verbose=True) #Aqui configuramos o estimador
xgb.fit(frases_transformadas_treino,senti_treino) #Iniciamos o treinamento
y_pred_xgb = arvore.predict(frases_transformadas_teste) # aqui eu não mostro o sentimento porque ele vai ter que advinhar
score_xgb = arvore.score(frases_transformadas_teste, senti_teste) #ver o percentual de acerto
print(score_xgb)
confusion_matrix(senti_teste,y_pred_xgb)

# %%
report=classification_report(y_true=senti_teste,y_pred=y_pred_xgb)
print(report) #Mostra as métricas de resultado do modelo

# %%
plot_confusion_matrix(xgb, frases_transformadas_teste,senti_teste, cmap=plt.cm.Reds,normalize='true')

# %% [markdown]
# ### Testando com frases aleatórias criadas por vocês, que não estavam na base

# %%
#frase_nova = ['Fiquei muito feliz em saber deste novo curso oferecido na Etec']
#frase_nova = ['Socorro estou sendo assaltado']
#frase_nova =['estou sentindo arrepios de medo acho que vi um fantasma']
#frase_nova = ['Nossa estou muito feliz porque acabei de chegar em casa e vou jogar video game']
frase_nova = ['Eu me sinto péssimo quando você não vem']
# convertendo a frase em números
frase_nova_convertida = vectorizer.transform(frase_nova)
y_pred_xgb_unica = xgb.predict(frase_nova_convertida) # aqui eu coloco para o modelo advinhar a nova frase
y_pred_xgb_unica

# %%
percentual_acerto = arvore.predict_proba(frase_nova_convertida)
percentual_acerto

# %% [markdown]
# ## SGDC

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.calibration import CalibratedClassifierCV

# %%
sgdc = SGDClassifier(max_iter=3000, tol=1e-3, n_iter_no_change = 20, eta0=0.4, learning_rate = 'adaptive')
sgdc.fit(frases_transformadas_treino,senti_treino) #treinamento
calibrator = CalibratedClassifierCV(sgdc, cv='prefit') #Calibração para prever o percentual futuramente
model_sgdc = calibrator.fit(frases_transformadas_treino,senti_treino) #treinamento com a calibração
y_pred_sgd = model_sgdc.predict(frases_transformadas_teste) # previsões com a nova base
score_sgd = model_sgdc.score(frases_transformadas_teste, senti_teste) #percentual de acerto do modelo com a base de teste
print(score_sgd)
confusion_matrix(senti_teste,y_pred_sgd) #Gera a matriz de confusão

# %%
report=classification_report(y_true=senti_teste,y_pred=y_pred_sgd)
print(report) #Mostra as métricas de resultado do modelo

# %%
plot_confusion_matrix(model_sgdc, frases_transformadas_teste,senti_teste, cmap=plt.cm.Reds,normalize='true')

# %% [markdown]
# ### Testando com frases aleatórias criadas por vocês, que não estavam na base

# %%
#frase_nova = ['Fiquei muito feliz em saber deste novo curso oferecido na Etec']
frase_nova = ['Socorro estou sendo assaltado']
#frase_nova =['estou sentindo arrepios de medo acho que vi um fantasma']
#frase_nova = ['Nossa estou muito feliz porque acabei de chegar em casa e vou jogar video game']
# convertendo a frase em números
frase_nova_convertida = vectorizer.transform(frase_nova)
y_pred_sgdc_unica = model_sgdc.predict(frase_nova_convertida) # aqui eu coloco para o modelo advinhar a nova frase
y_pred_sgdc_unica

# %%
percentual_acerto = model_sgdc.predict_proba(frase_nova_convertida)
percentual_acerto
